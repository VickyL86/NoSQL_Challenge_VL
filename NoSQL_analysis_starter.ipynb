# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %% [markdown]
# Copy the text you used to import your data from your Terminal to a markdown cell in your notebook:
#
# mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
#pretty print the first document in the collection
establishments.find_one()
# Out:
# {'_id': ObjectId('64be78c842e66641a3b0dcc1'),
#  'FHRSID': 1349980,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000084064',
#  'BusinessName': 'Boodles',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': '3 The Droveway',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT15 6DH',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2021-06-14T00:00:00',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.378536', 'latitude': '51.150879'},
#  'RightToReply': '',
#  'Distance': 4587.638929767669,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1349980'}]}

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 0}

# Use count_documents to display the number of documents in the result
print("Number of establishments with a hygiene score of 20:",establishments.count_documents(query))

# Display the first document in the results using pprint
print("First Result:")
results = establishments.find(query)
pprint(results[0])
# Out:
# Number of establishments with a hygiene score of 20: 17304
# First Result:
# {'AddressLine1': '3 The Droveway',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Boodles',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.638929767669,
#  'FHRSID': 1349980,
#  'LocalAuthorityBusinessID': 'PI/000084064',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DH',
#  'RatingDate': '2021-06-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64be78c842e66641a3b0dcc1'),
#  'geocode': {'latitude': '51.150879', 'longitude': '1.378536'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1349980',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %%
# Convert the result to a Pandas DataFrame
Hygiene_20 = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print("Number of rows in DataFrame:",len(Hygiene_20))
# Display the first 10 rows of the DataFrame
Hygiene_20.head(10)
# Out:
# Number of rows in DataFrame: 17304
#                         _id   FHRSID  ChangesByServerID  \
# 0  64be78c842e66641a3b0dcc1  1349980                  0
# 1  64be78c842e66641a3b0dcc2  1034540                  0
# 2  64be78c842e66641a3b0dcc3   254410                  0
# 3  64be78c842e66641a3b0dcc4  1030622                  0
# 4  64be78c842e66641a3b0dcc6   429991                  0
# 5  64be78c842e66641a3b0dcc7   466211                  0
# 6  64be78c842e66641a3b0dcc8   962759                  0
# 7  64be78c842e66641a3b0dcca  1376311                  0
# 8  64be78c842e66641a3b0dccb   254239                  0
# 9  64be78c842e66641a3b0dccc  1205250                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000084064                              Boodles
# 1             PI/000078691                   The Coastguard Inn
# 2             PI/000053944    St Margarets At Cliffe C P School
# 3             PI/000078259                  Portal House School
# 4             PI/000055200                  Mrs Knotts Tea Room
# 5             PI/000070896                     The White Cliffs
# 6             PI/000077707                     The Village Shop
# 7             PI/000084109  St Margaret's Bowls and Social Club
# 8             PI/000068711                 Boat House & Langdon
# 9             PI/000081301           Goodwins Suite (Reception)
#
#                 BusinessType  BusinessTypeID  \
# 0    Restaurant/Cafe/Canteen               1
# 1          Pub/bar/nightclub            7843
# 2  School/college/university            7845
# 3  School/college/university            7845
# 4    Restaurant/Cafe/Canteen               1
# 5    Restaurant/Cafe/Canteen               1
# 6          Retailers - other            4613
# 7    Restaurant/Cafe/Canteen               1
# 8    Restaurant/Cafe/Canteen               1
# 9          Pub/bar/nightclub            7843
#
#                           AddressLine1               AddressLine2  \
# 0                       3 The Droveway           St Margarets Bay
# 1                              The Bay           St Margarets Bay
# 2                           Sea Street     St Margarets At Cliffe
# 3                           Sea Street     St Margarets At Cliffe
# 4                         West Cottage  South Foreland Lighthouse
# 5                          High Street     St Margarets At Cliffe
# 6                          High Street     St Margarets At Cliffe
# 7                         Bowling Club          13 Kingsdown Road
# 8  St Margarets Hotel And Country Club                 Reach Road
# 9       Kingsdown Park Holiday Village               Upper Street
#
#              AddressLine3  ...     LocalAuthorityWebSite  \
# 0                    Kent  ...  http://www.dover.gov.uk/
# 1                    Kent  ...  http://www.dover.gov.uk/
# 2                    Kent  ...  http://www.dover.gov.uk/
# 3                    Kent  ...  http://www.dover.gov.uk/
# 4               The Front  ...  http://www.dover.gov.uk/
# 5                    Kent  ...  http://www.dover.gov.uk/
# 6                    Kent  ...  http://www.dover.gov.uk/
# 7  St Margarets At Cliffe  ...  http://www.dover.gov.uk/
# 8  St Margarets At Cliffe  ...  http://www.dover.gov.uk/
# 9               Kingsdown  ...  http://www.dover.gov.uk/
#
#       LocalAuthorityEmailAddress  \
# 0  publicprotection@dover.gov.uk
# 1  publicprotection@dover.gov.uk
# 2  publicprotection@dover.gov.uk
# 3  publicprotection@dover.gov.uk
# 4  publicprotection@dover.gov.uk
# 5  publicprotection@dover.gov.uk
# 6  publicprotection@dover.gov.uk
# 7  publicprotection@dover.gov.uk
# 8  publicprotection@dover.gov.uk
# 9  publicprotection@dover.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 8  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': '1.378536', 'latitude': '51.1508...
# 1  {'longitude': '1.387974', 'latitude': '51.1522...
# 2  {'longitude': '1.375095', 'latitude': '51.1529...
# 3  {'longitude': '1.375095', 'latitude': '51.1529...
# 4  {'longitude': '1.371894', 'latitude': '51.14061'}
# 5  {'longitude': '1.372341', 'latitude': '51.1537...
# 6  {'longitude': '1.371543', 'latitude': '51.1540...
# 7  {'longitude': '1.37213003635406', 'latitude': ...
# 8  {'longitude': '1.366199', 'latitude': '51.1503...
# 9  {'longitude': '1.402478', 'latitude': '51.1852...
#
#       Distance NewRatingPending  \
# 0  4587.638930            False
# 1  4587.347175            False
# 2  4587.840617            False
# 3  4587.840617            False
# 4  4587.492468            False
# 5  4587.973462            False
# 6  4588.011450            False
# 7  4588.057642            False
# 8  4588.067654            False
# 9  4588.068756            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'https://api.ratings....
# 8  [{'rel': 'self', 'href': 'https://api.ratings....
# 9  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query =

# Use count_documents to display the number of documents in the result

# Display the first document in the results using pprint

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 
longitude = 

query = 
sort =  

# Print the results

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
